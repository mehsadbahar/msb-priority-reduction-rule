# %% [markdown]
# # MSB Priority Reduction - Simulation & Analysis
#
# این نوت‌بوک الگوریتم کاهش اولویت به روش round-robin را تحلیل و مصورسازی می‌کند.

# %%
# ایمپورت کتابخانه‌ها
import sys
import os
sys.path.append('../src')

from msb_priority_reduction import msb_priority_reduction

print("✅ ماژول بارگذاری شد!")

# تست ساده
vector = [3, 2, 1, 1]
sequence = msb_priority_reduction(vector)

print(f"ورودی: {vector}")
print(f"تعداد گام‌ها: {len(sequence) - 1}")
print(f"توالی:")
for i, state in enumerate(sequence):
    print(f"Step {i}: {state}")
