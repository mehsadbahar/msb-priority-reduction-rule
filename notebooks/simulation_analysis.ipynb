# %% [markdown]
# # MSB Priority Reduction - Simulation & Analysis
#
# This notebook analyzes and visualizes the round-robin priority reduction algorithm.

# %%
# Import libraries
import sys
import os
sys.path.append('../src')

from msb_priority_reduction import msb_priority_reduction

print("✅ Module loaded successfully!")

# Simple test
vector = [3, 2, 1, 1]
sequence = msb_priority_reduction(vector)

print(f"Input vector: {vector}")
print(f"Number of steps: {len(sequence) - 1}")
print(f"Sequence:")
for i, state in enumerate(sequence):
    print(f"Step {i}: {state}")
